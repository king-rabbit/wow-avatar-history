# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('wowah_data.csv')

# %%
df.head()
# Out:
#     char   level  race  charclass                zone   guild  \
# 0  59425       1   Orc      Rogue           Orgrimmar     165
# 1  65494       9   Orc     Hunter             Durotar      -1
# 2  65325      14   Orc    Warrior          Ghostlands      -1
# 3  65490      18   Orc     Hunter          Ghostlands      -1
# 4   2288      60   Orc     Hunter  Hellfire Peninsula      -1
#
#            timestamp
# 0  01/01/08 00:02:04
# 1  01/01/08 00:02:04
# 2  01/01/08 00:02:04
# 3  01/01/08 00:02:04
# 4  01/01/08 00:02:09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10826734 entries, 0 to 10826733
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   char        int64
#  1    level      int64
#  2    race       object
#  3    charclass  object
#  4    zone       object
#  5    guild      int64
#  6    timestamp  object
# dtypes: int64(3), object(4)
# memory usage: 578.2+ MB

# %%
## 전처리

# %%
# 컬럼명에 있는 공백 제거
for col in df.columns:
    df = df.rename(columns={col:col.strip()})

# %%
# timestamp 컬럼 datetime 유형으로 변경
df['time'] = pd.to_datetime(df['timestamp'])

# %%
df = df.rename(columns={'time':'datetime'})

# %%
df['year'] = df['datetime'].dt.year  
df['month'] = df['datetime'].dt.month

# %%
df['date'] = df['datetime'].dt.date  
df['time'] = df['datetime'].dt.time

# %%
df.to_csv('wowah_data_re.csv')

# %%
df = pd.read_csv('wowah_data_re.csv')

# %%
#dau
dau = pd.DataFrame(df.groupby('date').char.nunique())

# %%
dau = dau.reset_index()

# %%
#mau
mau = pd.DataFrame(df.groupby(by=['year','month']).char.nunique())

# %%
mau = mau.reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (10,4))
sns.set(style='darkgrid')
sns.lineplot(x='date', y='char', data=dau) #line plot과 구간 평균/분포로 계산됨
# Out:
# <AxesSubplot:xlabel='date', ylabel='char'>

# %%
for i in range(len(mau)):
    mau.loc[i, 'time'] = str(mau.loc[i, 'year']) + '-' + str(mau.loc[i, 'month'])

# %%
plt.figure(figsize = (10,4))
sns.lineplot(x='time', y='char', data=mau, sort=0)
# Out:
# <AxesSubplot:xlabel='time', ylabel='char'>

# %%
# retention rate

# %%
df['date'][0].strftime('%Y-%m')
# Out:
# '2008-01'

# %%
#유저별로 첫번째 접속한 날짜
first_login = df.groupby(by=['char'])['date'].min().reset_index()

# %%
first_login = first_login.rename(columns={'date':'first_date'})

# %%
df_merged = pd.merge(df, first_login, how='left', on='char')

# %%
df_merged['day_played'] = df_merged['date'] - df_merged['first_date']

# %%
cohort_played = pd.pivot_table(df_merged, index=['first_date'], columns =['day_played'], values='char', aggfunc=pd.Series.nunique)

# %%
retention = []
for col in cohort_played.columns:
    retention_i = cohort_played[col].fillna(0).sum() / (cohort_played[col].fillna(0).astype('bool').astype('int') * cohort_played['0 days']).sum()
    retention.append(retention_i)

# %%
plt.figure(figsize = (20,8))
sns.lineplot(x=cohort_played.columns[1:], y=retention[1:])
# Out:
# <AxesSubplot:xlabel='day_played'>

# %%
# average play time

# %%
playtime = df.groupby(by=['date', 'char']).time.agg(['min', 'max']).reset_index()

# %%
from datetime import datetime, timedelta

playtime['start_time'] = [datetime.combine(datetime.today(), time) for time in playtime['min']]
playtime['end_time'] = [datetime.combine(datetime.today(), time) for time in playtime['max']]

# %%
playtime['duration'] = playtime['end_time'] - playtime['start_time']

# %%
playtime['duration'] = [(time.total_seconds() / 3600) for time in playtime['duration']]

# %%
playtime_average = playtime.groupby(by=['date']).duration.mean()

# %%
playtime_average.mean()
# Out:
# 7.604747928370665

# %%
#guild

# %%
#총 길드 개수
df.guild.nunique()
# Out:
# 420

# %%
noguild_user = df[df.guild==-1].reset_index()
noguild_daily = noguild_user.groupby('date').char.nunique().reset_index()

# %%
noguild_daily = pd.merge(dau, noguild_daily, how='left', on='date')

# %%
noguild_daily = noguild_daily.rename(columns={'char_x':'dau', 'char_y':'noguild'})

# %%
noguild_daily['noguild_perc'] = noguild_daily['noguild'] / noguild_daily['dau']

# %%
#dau 중 길드가 없는 유저의 비율
plt.figure(figsize = (10,4))
sns.lineplot(x='date', y='noguild_perc', data=noguild_daily, sort=0)
# Out:
# <AxesSubplot:xlabel='date', ylabel='noguild_perc'>

# %%
guild_size = df.groupby(by=['guild']).char.nunique().reset_index()

# %%
guild_size = guild_size[guild_size.guild!=-1]

# %%
#대부분 소규모 길드이며 가장 규모가 큰 길드가 1750여명 정도임.
sns.distplot(guild_size['char'])
# Out:
# <AxesSubplot:xlabel='char'>

# %%
#규모가 가장 큰 길드 10곳
top_guilds = guild_size.sort_values(by='char', ascending=False)[:10]

# %%
list(top_guilds.guild)
# Out:
# [460, 282, 103, 251, 101, 161, 189, 104, 35, 204]

# %%
top_guild_users = df[df.guild.isin(list(top_guilds.guild))].reset_index()

# %%
top_guild_size = top_guild_users.groupby(by=['guild', 'date']).char.nunique().reset_index()

# %%
top_guild_size.guild = top_guild_size.guild.astype('str')

# %%
top_guild_size.guild = 'g_' + top_guild_size.guild

# %%
plt.figure(figsize = (20,8))
sns.lineplot(x='date', y='char', data=top_guild_size, hue='guild')
# Out:
# <AxesSubplot:xlabel='date', ylabel='char'>

# %% [markdown]
# * 460번 길드는 2008년 10월경 신설된 후 접속자 수가 폭발적으로 늘었으나 이후 급감 : 아마 신규 확장팩 런칭 영향으로 보임

# %%
df = df.sort_values(by=['char', 'datetime']).reset_index()

# %%
df
# Out:
#              index   char  level       race charclass            zone  guild  \
# 0         10114236      2     18        Orc    Shaman     The Barrens      6
# 1           622587      7     54        Orc    Hunter         Feralas     -1
# 2           623200      7     54        Orc    Hunter  Un'Goro Crater     -1
# 3           623826      7     54        Orc    Hunter     The Barrens     -1
# 4           624439      7     54        Orc    Hunter        Badlands     -1
# ...            ...    ...    ...        ...       ...             ...    ...
# 10826729  10823949  90577      2  Blood Elf   Warlock  Eversong Woods     -1
# 10826730  10824466  90577      3  Blood Elf   Warlock  Eversong Woods     -1
# 10826731  10823948  90578      1  Blood Elf   Paladin  Eversong Woods     -1
# 10826732  10824134  90579      1        Orc   Warrior         Durotar     -1
# 10826733  10825225  90580      1     Tauren   Warrior         Mulgore     -1
#
#                   timestamp            datetime
# 0         12/03/08 10:41:47 2008-12-03 10:41:47
# 1         01/15/08 21:47:09 2008-01-15 21:47:09
# 2         01/15/08 21:56:54 2008-01-15 21:56:54
# 3         01/15/08 22:07:23 2008-01-15 22:07:23
# 4         01/15/08 22:17:08 2008-01-15 22:17:08
# ...                     ...                 ...
# 10826729  12/31/08 22:32:52 2008-12-31 22:32:52
# 10826730  12/31/08 22:47:54 2008-12-31 22:47:54
# 10826731  12/31/08 22:32:52 2008-12-31 22:32:52
# 10826732  12/31/08 22:44:45 2008-12-31 22:44:45
# 10826733  12/31/08 23:15:20 2008-12-31 23:15:20
#
# [10826734 rows x 9 columns]

# %%
session_init = 1
df.loc[0, 'session'] = session_init

for i in range(1, len(df[:100000])):
    if df.loc[i, 'char'] != df.loc[i-1, 'char'] :
        session_init = 1
    elif (df.loc[i, 'char'] == df.loc[i-1, 'char']) and (df.loc[i, 'datetime'] - df.loc[i-1, 'datetime']).total_seconds()/60 > 15:
        session_init += 1
    else: 
        pass
        
    df.loc[i, 'session'] = session_init
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-426733a01be6> in <module>
#      10         pass
#      11
# ---> 12     df.loc[i, 'session'] = session_init
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1761                 # scalar value
#    1762                 for loc in ilocs:
# -> 1763                     isetter(loc, value)
#    1764
#    1765         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in isetter(loc, v)
#    1686                 else:
#    1687                     # set the item, possibly having a dtype change
# -> 1688                     ser = ser.copy()
#    1689                     ser._mgr = ser._mgr.setitem(indexer=plane_indexer, value=v)
#    1690                     ser._maybe_update_cacher(clear=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5663         dtype: object
#    5664         """
# -> 5665         data = self._mgr.copy(deep=deep)
#    5666         self._clear_item_cache()
#    5667         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     809             new_axes = list(self.axes)
#     810
# --> 811         res = self.apply("copy", deep=deep)
#     812         res.axes = new_axes
#     813         return res
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     407                 applied = b.apply(f, **kwargs)
#     408             else:
# --> 409                 applied = getattr(b, f)(**kwargs)
#     410             result_blocks = _extend_blocks(applied, result_blocks)
#     411
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     677         values = self.values
#     678         if deep:
# --> 679             values = values.copy()
#     680         return self.make_block_same_class(values, ndim=self.ndim)
#     681
#
# KeyboardInterrupt:

# %%
df[~df.session.isna()]
# Out:
#          index  char  level race charclass            zone  guild  \
# 0     10114236     2     18  Orc    Shaman     The Barrens      6
# 1       622587     7     54  Orc    Hunter         Feralas     -1
# 2       623200     7     54  Orc    Hunter  Un'Goro Crater     -1
# 3       623826     7     54  Orc    Hunter     The Barrens     -1
# 4       624439     7     54  Orc    Hunter        Badlands     -1
# ...        ...   ...    ...  ...       ...             ...    ...
# 5309   2488240    19     70  Orc     Rogue    Arathi Basin     65
# 5310   2488888    19     70  Orc     Rogue    Arathi Basin     65
# 5311   2489520    19     70  Orc     Rogue    Arathi Basin     65
# 5312   2490126    19     70  Orc     Rogue     Zangarmarsh     65
# 5313   2490692    19     70  Orc     Rogue     Zangarmarsh     65
#
#               timestamp            datetime  session
# 0     12/03/08 10:41:47 2008-12-03 10:41:47      1.0
# 1     01/15/08 21:47:09 2008-01-15 21:47:09      1.0
# 2     01/15/08 21:56:54 2008-01-15 21:56:54      1.0
# 3     01/15/08 22:07:23 2008-01-15 22:07:23      1.0
# 4     01/15/08 22:17:08 2008-01-15 22:17:08      1.0
# ...                 ...                 ...      ...
# 5309  02/28/08 23:25:54 2008-02-28 23:25:54    136.0
# 5310  02/28/08 23:35:53 2008-02-28 23:35:53    136.0
# 5311  02/28/08 23:46:33 2008-02-28 23:46:33    136.0
# 5312  02/28/08 23:56:01 2008-02-28 23:56:01    136.0
# 5313  02/29/08 00:06:11 2008-02-29 00:06:11    136.0
#
# [5314 rows x 10 columns]

# %%
df[df.session.isna()]
# Out:
#              index   char  level       race charclass            zone  guild  \
# 5314       2491218     19     70        Orc     Rogue     Zangarmarsh     65
# 5315       2491706     19     70        Orc     Rogue     Zangarmarsh     65
# 5316       2492160     19     70        Orc     Rogue     Zangarmarsh     65
# 5317       2492554     19     70        Orc     Rogue     Zangarmarsh     65
# 5318       2492907     19     70        Orc     Rogue     Zangarmarsh     65
# ...            ...    ...    ...        ...       ...             ...    ...
# 10826729  10823949  90577      2  Blood Elf   Warlock  Eversong Woods     -1
# 10826730  10824466  90577      3  Blood Elf   Warlock  Eversong Woods     -1
# 10826731  10823948  90578      1  Blood Elf   Paladin  Eversong Woods     -1
# 10826732  10824134  90579      1        Orc   Warrior         Durotar     -1
# 10826733  10825225  90580      1     Tauren   Warrior         Mulgore     -1
#
#                   timestamp            datetime  session
# 5314      02/29/08 00:15:54 2008-02-29 00:15:54      NaN
# 5315      02/29/08 00:26:04 2008-02-29 00:26:04      NaN
# 5316      02/29/08 00:46:05 2008-02-29 00:46:05      NaN
# 5317      02/29/08 00:55:53 2008-02-29 00:55:53      NaN
# 5318      02/29/08 01:05:56 2008-02-29 01:05:56      NaN
# ...                     ...                 ...      ...
# 10826729  12/31/08 22:32:52 2008-12-31 22:32:52      NaN
# 10826730  12/31/08 22:47:54 2008-12-31 22:47:54      NaN
# 10826731  12/31/08 22:32:52 2008-12-31 22:32:52      NaN
# 10826732  12/31/08 22:44:45 2008-12-31 22:44:45      NaN
# 10826733  12/31/08 23:15:20 2008-12-31 23:15:20      NaN
#
# [10821420 rows x 10 columns]

# %% [markdown]
# #session
#
# session_init = 1
# df.loc[0, 'session'] = session_init
#
# for i in range(1, len(df)):
#     if df.loc[i, 'char'] != df.loc[i-1, 'char'] :
#         session_init = 1
#     elif df.loc[i, 'char'] == df.loc[i-1, 'char'] and (df.loc[i, 'datetime'] - df.loc[i-1, 'datetime']).total_seconds()/60 > 15:
#         session_init += session_init
#     else:
#         pass
#
#     df.loc[i, 'session'] = session_init
